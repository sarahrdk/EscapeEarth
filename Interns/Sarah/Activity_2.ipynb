# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahrdk/EscapeEarth/blob/main/Interns/Sarah/Activity_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Activity 2 - jupyter

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls /content/gdrive/My\ Drive/EscapeEarthData/Activity-2
# Out:
# df1.csv  df2.csv  df3.csv  df4.csv  df5.csv  df6.csv  df7.csv  df8.csv

# %%
data1 = pd.read_csv('/content/gdrive/My Drive/EscapeEarthData/Activity-2/df1.csv') 
#'/content/gdrive/My Drive/EscapeEarthData/Activity-2/df1.csv'
#df1 = np.load("{}df1.csv".format(my_path))
#~Desktop/AMNH/BridgeUp Internship/Internship/EscapeEarth/interns/Activities/Data

# %%
(data2 = pd.read_csv('/content/gdrive/My Drive/EscapeEarthData/Activity-2/df2.csv') 
data3 = pd.read_csv('/content/gdrive/My Drive/EscapeEarthData/Activity-2/df3.csv') 
data4 = pd.read_csv('/content/gdrive/My Drive/EscapeEarthData/Activity-2/df4.csv') 
data5 = pd.read_csv('/content/gdrive/My Drive/EscapeEarthData/Activity-2/df5.csv')  
data6 = pd.read_csv('/content/gdrive/My Drive/EscapeEarthData/Activity-2/df6.csv') 
data7 = pd.read_csv('/content/gdrive/My Drive/EscapeEarthData/Activity-2/df7.csv') 
data8 = pd.read_csv('/content/gdrive/My Drive/EscapeEarthData/Activity-2/df8.csv')

# %%
data1.head()
# Out:
#        col1     col2
# 0  272.3966  45.8308
# 1  272.3288  45.9244
# 2  272.3307  45.9255
# 3  272.3711  47.2259
# 4  272.5282  47.0887

# %%
plt.scatter(data1["col1"], data1["col2"], s = 0.25)

# %%
plt.scatter(data2["col1"], data2["col2"], s = 0.25)

# %%
plt.scatter(data3["col1"], data3["col2"], s = 0.25)

# %%
plt.scatter(data4["col1"], data4["col2"], s = 0.25)

# %%
plt.scatter(data5["col1"], data5["col2"], s = 0.25)

# %%
plt.scatter(data6["col1"], data6["col2"], s = 0.25)

# %%
plt.scatter(data7["col1"], data7["col2"], s = 0.25)

# %%
plt.scatter(data8["col1"], data8["col2"], s = 0.25)

# %%
plt.scatter(data1["col1"], data1["col2"], s = 0.25, color = "darkviolet")
plt.scatter(data2["col1"], data2["col2"], s = 0.25, color = "mediumorchid")
plt.scatter(data3["col1"], data3["col2"], s = 0.25, color = "rebeccapurple")
plt.scatter(data4["col1"], data4["col2"], s = 0.25, color = "violet")
plt.scatter(data5["col1"], data5["col2"], s = 0.25, color = "purple")
plt.scatter(data6["col1"], data6["col2"], s = 0.25, color = "m")
plt.scatter(data7["col1"], data7["col2"], s = 0.25, color = "palevioletred")
plt.scatter(data8["col1"], data8["col2"], s = 0.25, color = "orchid")

# %% [markdown]
# # Activity 2 - continued

# %%
import astropy
from astropy.coordinates import SkyCoord

# %%
c_old = SkyCoord([data1['col1'].to_numpy()], [data1['col2'].to_numpy()], frame='icrs',unit='degree') #replace df1 if your variable names are different 
c_new = c_old.galactic
for count in range(len(c_new[0])):
        data1_new_col1 = c_new[0].l.degree
        data1_new_col2 = c_new[0].b.degree
new_data = {'col1':data1_new_col1,'col2':data1_new_col2}
data1_new = pd.DataFrame(new_data)

# %%
plt.scatter(data1_new["col1"], data1_new["col2"], s = 0.25)

# %%
c_old2 = SkyCoord([data2['col1'].to_numpy()], [data2['col2'].to_numpy()], frame='icrs',unit='degree') #replace df1 if your variable names are different 
c_new2 = c_old2.galactic
for count in range(len(c_new2[0])):
        data2_new_col1 = c_new2[0].l.degree
        data2_new_col2 = c_new2[0].b.degree
new_data2 = {'col1':data2_new_col1,'col2':data2_new_col2}
data2_new = pd.DataFrame(new_data2)

# %%
plt.scatter(data2_new["col1"], data2_new["col2"], s = 0.25)

# %%
c_old3 = SkyCoord([data3['col1'].to_numpy()], [data3['col2'].to_numpy()], frame='icrs',unit='degree') #replace df1 if your variable names are different 
c_new3 = c_old3.galactic
for count in range(len(c_new3[0])):
        data3_new_col1 = c_new3[0].l.degree
        data3_new_col2 = c_new3[0].b.degree
new_data3 = {'col1':data3_new_col1,'col2':data3_new_col2}
data3_new = pd.DataFrame(new_data3)

# %%
plt.scatter(data3_new["col1"], data3_new["col2"], s = 0.25)

# %%
c_old4 = SkyCoord([data4['col1'].to_numpy()], [data4['col2'].to_numpy()], frame='icrs',unit='degree') #replace df1 if your variable names are different 
c_new4 = c_old4.galactic
for count in range(len(c_new4[0])):
        data4_new_col1 = c_new4[0].l.degree
        data4_new_col2 = c_new4[0].b.degree
new_data4 = {'col1':data4_new_col1,'col2':data4_new_col2}
data4_new = pd.DataFrame(new_data4)

# %%
plt.scatter(data4_new["col1"], data4_new["col2"], s = 0.25)

# %%
c_old5 = SkyCoord([data5['col1'].to_numpy()], [data5['col2'].to_numpy()], frame='icrs',unit='degree') #replace df1 if your variable names are different 
c_new5 = c_old.galactic
for count in range(len(c_new5[0])):
        data5_new_col1 = c_new5[0].l.degree
        data5_new_col2 = c_new5[0].b.degree
new_data5 = {'col1':data5_new_col1,'col2':data5_new_col2}
data5_new = pd.DataFrame(new_data5)

# %%
plt.scatter(data5_new["col1"], data5_new["col2"], s = 0.25)

# %%
c_old6 = SkyCoord([data6['col1'].to_numpy()], [data6['col2'].to_numpy()], frame='icrs',unit='degree') #replace df1 if your variable names are different 
c_new6 = c_old6.galactic
for count in range(len(c_new6[0])):
        data6_new_col1 = c_new6[0].l.degree
        data6_new_col2 = c_new6[0].b.degree
new_data6 = {'col1':data6_new_col1,'col2':data6_new_col2}
data6_new = pd.DataFrame(new_data6)

# %%
plt.scatter(data6_new["col1"], data6_new["col2"], s = 0.25)

# %%
c_old7 = SkyCoord([data7['col1'].to_numpy()], [data7['col2'].to_numpy()], frame='icrs',unit='degree') #replace df1 if your variable names are different 
c_new7 = c_old7.galactic
for count in range(len(c_new7[0])):
        data7_new_col1 = c_new7[0].l.degree
        data7_new_col2 = c_new7[0].b.degree
new_data7 = {'col1':data7_new_col1,'col2':data7_new_col2}
data7_new = pd.DataFrame(new_data7)

# %%
plt.scatter(data7_new["col1"], data7_new["col2"], s = 0.25)

# %%
c_old8 = SkyCoord([data8['col1'].to_numpy()], [data8['col2'].to_numpy()], frame='icrs',unit='degree') #replace df1 if your variable names are different 
c_new8 = c_old8.galactic
for count in range(len(c_new8[0])):
        data8_new_col1 = c_new8[0].l.degree
        data8_new_col2 = c_new8[0].b.degree
new_data8 = {'col1':data8_new_col1,'col2':data8_new_col2}
data8_new = pd.DataFrame(new_data8)

# %%
plt.scatter(data8_new["col1"], data8_new["col2"], s = 0.25)

# %%
plt.scatter(data1_new["col1"], data1_new["col2"], s = 0.25, color = "darkviolet")
plt.scatter(data2_new["col1"], data2_new["col2"], s = 0.25, color = "mediumorchid")
plt.scatter(data3_new["col1"], data3_new["col2"], s = 0.25, color = "rebeccapurple")
plt.scatter(data4_new["col1"], data4_new["col2"], s = 0.25, color = "violet")
plt.scatter(data5_new["col1"], data5_new["col2"], s = 0.25, color = "purple")
plt.scatter(data6_new["col1"], data6_new["col2"], s = 0.25, color = "m")
plt.scatter(data7_new["col1"], data7_new["col2"], s = 0.25, color = "palevioletred")
plt.scatter(data8_new["col1"], data8_new["col2"], s = 0.25, color = "orchid")
