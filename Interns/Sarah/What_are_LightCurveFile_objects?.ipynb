# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahrdk/EscapeEarth/blob/main/Interns/Sarah/What_are_LightCurveFile_objects%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install lightkurve

# %%
#fetch from data archive
from lightkurve import search_lightcurvefile
lcf = search_lightcurvefile('KIC 6922244', quarter=4).download()

# %%
#plots both flux
lcf.plot();

# %%
#plots pdcsap flux
pdcsap = lcf.PDCSAP_FLUX

# %%
#plots sap flux
sapflux = lcf.SAP_FLUX

# %%
#creates a KeplerLightCurve object only containing pdcsap flux
lcf
pdcsap
# Out:
# KeplerLightCurve(ID: 6922244)

# %%
pdcsap.mission
# Out:
# 'Kepler'

# %%
pdcsap.quarter
# Out:
# 4

# %%
pdcsap.estimate_cdpp()
# Out:
# 58.91594464222756
